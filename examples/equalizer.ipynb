# %%
$LOAD_PATH << File.dirname(__FILE__) + "/../lib"
require 'audio_stream'

include AudioStream
include AudioStream::Fx

soundinfo = SoundInfo.new(
  channels: 2,
  samplerate: 44100,
  window_size: 1024,
  format: RubyAudio::FORMAT_WAV|RubyAudio::FORMAT_PCM_16
)

eq = Equalizer2band.new(soundinfo, lowgain: 3, highgain: 5)
eq.plot.show
# Out:
# #<Plotly::Offline::HTML:0x00007fa557ba3200 @id="0ae942a3-74b0-4380-b3c1-ca50373f13a1", @data=[{:x=>[21.533203125, 21.833795438838024, 22.138583865006105, 22.44762697904955, 22.760984174197695, 23.07871567277857, 23.400882537792576, 23.72754668464773, 24.058770893059034, 24.394618819113624, 24.735155007504503, 25.08044490393502, 25.430554867696433, 25.785552184421263, 26.14550507901446, 26.51048272876506, 26.880555276641157, 27.255793844770185, 27.636270548107447, 28.022058508295558, 28.413231867717116, 28.809865803743918, 29.21203654318476, 29.61982137693493, 30.033298674830515, 30.452547900709714, 30.87764962768455, 31.30868555362585, 31.74573851686406, 32.18889251210976, 32.63823270659601, 33.09384545644599, 33.555818323269584, 34.02424009099115, 34.499200782912425, 34.980791679013684, 35.46910533349604, 35.96423559256943, 36.46627761248774, 36.97532787783684, 37.49148422007719, 38.01484583634559, 38.54551330851912, 39.08358862254568, 39.62917518804391, 40.18237785817697, 40.743302
# ...

# %%
$LOAD_PATH << File.dirname(__FILE__) + "/../lib"
require 'audio_stream'

include AudioStream
include AudioStream::Fx

soundinfo = SoundInfo.new(
  channels: 2,
  samplerate: 44100,
  window_size: 1024,
  format: RubyAudio::FORMAT_WAV|RubyAudio::FORMAT_PCM_16
)

eq = Equalizer3band.new(soundinfo, lowgain: 3, midgain: 1, highgain: 5)
eq.plot.show
# Out:
# #<Plotly::Offline::HTML:0x00007fa557bb9ca8 @id="9e7e2698-b9a5-4826-a3b0-1420d0a25aea", @data=[{:x=>[21.533203125, 21.833795438838024, 22.138583865006105, 22.44762697904955, 22.760984174197695, 23.07871567277857, 23.400882537792576, 23.72754668464773, 24.058770893059034, 24.394618819113624, 24.735155007504503, 25.08044490393502, 25.430554867696433, 25.785552184421263, 26.14550507901446, 26.51048272876506, 26.880555276641157, 27.255793844770185, 27.636270548107447, 28.022058508295558, 28.413231867717116, 28.809865803743918, 29.21203654318476, 29.61982137693493, 30.033298674830515, 30.452547900709714, 30.87764962768455, 31.30868555362585, 31.74573851686406, 32.18889251210976, 32.63823270659601, 33.09384545644599, 33.555818323269584, 34.02424009099115, 34.499200782912425, 34.980791679013684, 35.46910533349604, 35.96423559256943, 36.46627761248774, 36.97532787783684, 37.49148422007719, 38.01484583634559, 38.54551330851912, 39.08358862254568, 39.62917518804391, 40.18237785817697, 40.743302
# ...

# %%
$LOAD_PATH << File.dirname(__FILE__) + "/../lib"
require 'audio_stream'

include AudioStream
include AudioStream::Fx

soundinfo = SoundInfo.new(
  channels: 2,
  samplerate: 44100,
  window_size: 1024,
  format: RubyAudio::FORMAT_WAV|RubyAudio::FORMAT_PCM_16
)

eq = GraphicEqualizer.new(soundinfo)
  .add(freq: 100, gain: 8)
  .add(freq: 200, gain: 4)
  .add(freq: 400, gain: -4)
  .add(freq: 800, gain: -8)
  .add(freq: 1600, gain: 4)
  .add(freq: 3200, gain: 8)
eq.plot.show
# Out:
# #<Plotly::Offline::HTML:0x00007fa557b63ad8 @id="329d2ca0-6ac4-4a9e-abd7-1164093ff279", @data=[{:x=>[21.533203125, 21.833795438838024, 22.138583865006105, 22.44762697904955, 22.760984174197695, 23.07871567277857, 23.400882537792576, 23.72754668464773, 24.058770893059034, 24.394618819113624, 24.735155007504503, 25.08044490393502, 25.430554867696433, 25.785552184421263, 26.14550507901446, 26.51048272876506, 26.880555276641157, 27.255793844770185, 27.636270548107447, 28.022058508295558, 28.413231867717116, 28.809865803743918, 29.21203654318476, 29.61982137693493, 30.033298674830515, 30.452547900709714, 30.87764962768455, 31.30868555362585, 31.74573851686406, 32.18889251210976, 32.63823270659601, 33.09384545644599, 33.555818323269584, 34.02424009099115, 34.499200782912425, 34.980791679013684, 35.46910533349604, 35.96423559256943, 36.46627761248774, 36.97532787783684, 37.49148422007719, 38.01484583634559, 38.54551330851912, 39.08358862254568, 39.62917518804391, 40.18237785817697, 40.743302
# ...
